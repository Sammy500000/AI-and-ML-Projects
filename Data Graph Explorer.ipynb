# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io

# uploading it from the local computer
'''uploaded = files.upload()
file_name = next(iter(uploaded))
csv = pd.read_csv(io.BytesIO(uploaded[file_name]))

#getting a url from user input
input = input("Enter the CSV URL: ")
csv = pd.read_csv(input)'''

#putting the url in the code
url = 'https://media.geeksforgeeks.org/wp-content/uploads/nba.csv'
csv = pd.read_csv(url)

# %%
df = pd.DataFrame(csv)

# %%
print(df.head(2))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
headings = list(df.columns) #printing headings
print(headings)
# Out:
# ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
first_column = df['Team'].to_numpy
second_column = df['College'].to_numpy
print(second_column)
# Out:
# <bound method IndexOpsMixin.to_numpy of 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object>

# %%
first_column = df['Height'].head(20)
second_column = df['Weight'].head(20)

plt.plot(first_column, second_column, 'ro')
plt.plot(first_column, second_column, 'b')
